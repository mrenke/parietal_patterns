# %% [markdown]
# ## Visualize PFMs with Pycortex
#
#
#
# First attempts in numrisk/fmri_analysis/surface/vis_surface_....
# - ssh -L 8080:localhost:8000 scienccloud (808o = local portID, 8000 = remote portID)
# - in local webbrowser: http://localhost:8080/mixer.html (change 8000 (what opens as default) to 8080 !)- but you still need the localhost!
#
# multiple viewers: `ssh -L 8000:localhost:8000 -L 8001:localhost:8001 -L 8002:localhost:8002 sciencecloud`
# (just use same port ID on local and remote to make it easier)

# %%
from nilearn import image
from nilearn import surface
import os.path as op
import numpy as np
import nibabel as nib
import cortex

bids_folder_freesurfer = '/mnt_03/ds-dnumrisk'
bids_folder_data = '/mnt_AdaBD_largefiles/Data/SMILE_Data/DNumRisk/ds-dnumrisk'

# %%
sub = '46' #'average'
confspec = '36Pscrub3BPfilter'
task = 'magjudge'
ses = 1

space =  'fsnative' #'fsaverage' #
dataset = 'dnumrisk'

pyc_subject = space if space == 'fsaverage' else f'{dataset}.sub-{sub}'

source_folder = op.join(bids_folder_data,'derivatives','networks_infomap_full', f'sub-{sub}')

surf_L = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-L_consensus_labels.surf.gii'))
surf_R = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-R_consensus_labels.surf.gii'))

surf_map_fsnative = np.concatenate([surf_L, surf_R])
print(surf_map_fsnative.shape)
ds_1 = cortex.Vertex(surf_map_fsnative, pyc_subject)
cortex.webshow(ds_1, port=8001)  

# ssh -L 8080:localhost:8000 sciencecloud
# Out:
# (276298,)
# Generating new ctm file...
# wm
# wm
# inflated
# inflated
# Started server on port 8001
# <JS: window.viewer>

# %%
sub = '10' #'average'
confspec = '36Pscrub3BPfilter'
task = 'magjudge'
ses = 1

space = 'fsnative' #'fsaverage'
dataset = 'dnumrisk'

pyc_subject = space if space == 'fsaverage' else f'{dataset}.sub-{sub}'

source_folder = op.join(bids_folder_data,'derivatives','networks_infomap_full', f'sub-{sub}')

surf_L = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-L_consensus_labels.surf.gii'))
surf_R = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-R_consensus_labels.surf.gii'))

surf_map_fsnative = np.concatenate([surf_L, surf_R])
print(surf_map_fsnative.shape)
ds_1 = cortex.Vertex(surf_map_fsnative, pyc_subject)
cortex.webshow(ds_1, port=8001)  

# ssh -L 8080:localhost:8000 sciencecloud
# Out:
# (260565,)
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/serve.py", line 289, in run
#     self.server.listen(self.port)
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/tornado/tcpserver.py", line 183, in listen
#     sockets = bind_sockets(
#               ^^^^^^^^^^^^^
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/tornado/netutil.py", line 162, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [Errno 98] Address already in use
# Started server on port 8001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/utils.py:40, in DocLoader.__call__(self, *args, **kwargs)
#      39 def __call__(self, *args, **kwargs):
# ---> 40     return self._load()(*args, **kwargs)
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/view.py:918, in show(data, autoclose, open_browser, port, pickerfun, recache, template, overlays_available, overlays_visible, labels_visible, types, overlay_file, curvature_brightness, curvature_contrast, curvature_smoothness, surface_specularity, title, layout, **kwargs)
#     916 if open_browser:
#     917     webbrowser.open(url)
# --> 918     client = server.get_client()
#     919     client.server = server
#     920     return client
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/view.py:894, in show.<locals>.WebApp.get_client(self)
#     893 def get_client(self):
# --> 894     self.connect.wait()
#     895     self.connect.clear()
#     896     return JSMixer(self.send, "window.viewer")
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
# Both: gradients and network labels

sub = '10' #'average'
task = 'magjudge'
ses = 1

space = 'fsnative' #'fsaverage'
dataset = 'dnumrisk'

pyc_subject = space if space == 'fsaverage' else f'{dataset}.sub-{sub}'

source_folder = op.join(bids_folder_data,'derivatives','networks_infomap_full', f'sub-{sub}')
surf_L = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-L_consensus_labels.surf.gii'))
surf_R = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-R_consensus_labels.surf.gii'))
surf_map_fsnative_1 = np.concatenate([surf_L, surf_R])

grad_n = 2
source_folder = op.join(bids_folder_data,'derivatives','gradients.36Pscrub3BPfilterrunFD104', f'sub-{sub}')
surf_L = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-L_grad-{grad_n}.surf.gii'))
surf_R = surface.load_surf_data(op.join(source_folder, f'sub-{sub}_ses-{ses}_task-{task}_space-{space}_hemi-R_grad-{grad_n}.surf.gii'))
surf_map_fsnative_2 = np.concatenate([surf_L, surf_R])

v1 = cortex.Vertex(surf_map_fsnative_1, pyc_subject)
v2 = cortex.Vertex(surf_map_fsnative_2, pyc_subject)

ds = cortex.Dataset(
    networks=v1,
    gradient=v2
)
cortex.webshow(ds, port=8002)

# ssh -L 8080:localhost:8000 sciencecloud
# Out:
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/serve.py", line 289, in run
#     self.server.listen(self.port)
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/tornado/tcpserver.py", line 183, in listen
#     sockets = bind_sockets(
#               ^^^^^^^^^^^^^
#   File "/home/ubuntu/miniconda3/envs/pycortex/lib/python3.12/site-packages/tornado/netutil.py", line 162, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [Errno 98] Address already in use
# Started server on port 8002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 30
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/utils.py:40, in DocLoader.__call__(self, *args, **kwargs)
#      39 def __call__(self, *args, **kwargs):
# ---> 40     return self._load()(*args, **kwargs)
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/view.py:918, in show(data, autoclose, open_browser, port, pickerfun, recache, template, overlays_available, overlays_visible, labels_visible, types, overlay_file, curvature_brightness, curvature_contrast, curvature_smoothness, surface_specularity, title, layout, **kwargs)
#     916 if open_browser:
#     917     webbrowser.open(url)
# --> 918     client = server.get_client()
#     919     client.server = server
#     920     return client
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/site-packages/cortex/webgl/view.py:894, in show.<locals>.WebApp.get_client(self)
#     893 def get_client(self):
# --> 894     self.connect.wait()
#     895     self.connect.clear()
#     896     return JSMixer(self.send, "window.viewer")
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/pycortex/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
