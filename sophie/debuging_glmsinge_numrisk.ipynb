# %%
import nibabel as nib
import os.path as op

bids_folder = '/mnt_AdaBD_largefiles/Data/SMILE_DATA/DNumRisk/ds-numrisk'

sub = '20'
for run in range(1, 7):
    path = op.join(bids_folder, 'derivatives', 'fmriprep', f'sub-{sub}', 'ses-1', 'func',
                   f'sub-{sub}_ses-1_task-magjudge_run-{run}_space-T1w_desc-preproc_bold.nii.gz')
    img = nib.load(path)
    print(f'run {run}: {img.shape}')
# Out:
# run 1: (56, 71, 52, 189)
# run 2: (56, 71, 52, 189)
# run 3: (56, 71, 52, 189)
# run 4: (56, 71, 52, 189)
# run 5: (56, 71, 52, 189)
# run 6: (56, 71, 52, 189)
