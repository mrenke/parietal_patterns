# %% [markdown]
# - ssh -L 8000:localhost:8000 sciencecloud
# - in local webbrowser: http://localhost:8000/mixer.html
#
# check https://gallantlab.org/pycortex/auto_examples/utils/index.html

# %%
from nilearn import image
from nilearn import surface
import os.path as op
import numpy as np
import matplotlib.pyplot as plt

bids_folder_orig = '/mnt_03/ds-dnumrisk'
bids_folder = '/mnt_AdaBD_largefiles/Data/SMILE_DATA/DNumRisk/ds-dnumrisk'

space = 'fsaverage'
pyc_subject = space if space == 'fsaverage' else f'{dataset}.sub-{subject:02d}'

import cortex
cortex.database.default_filestore
# Out:
# '/home/ubuntu/miniconda3/envs/pycortex/share/pycortex/db'

# %%
import pandas as pd
grad_n = 2
confspec = '32Pscrub3BPfilterrunFD104'
newConf32_NPCdisper = pd.read_csv(op.join(bids_folder_orig, 'derivatives', 'phenotype',f'withinNdispersion-NPC_grad-{grad_n}_confspec-{confspec}.csv' )).set_index('subject')
newConf32_NPCdisper.sort_values(by='NPC_dispersion')
# Out:
#          group  NPC_dispersion  NPC_centroid
# subject
# 63           0        1.323412     -0.197495
# 66           0        1.707363      0.600399
# 3            0        1.771344      0.268926
# 59           0        1.868535     -0.365539
# 1            0        1.985013      1.838762
# ...        ...             ...           ...
# 40           1       15.063349     -0.586994
# 33           1       15.377733      1.540902
# 27           1       15.561985      0.103130
# 46           1       24.668012     -1.687539
# 6            1       73.113322      4.676277
#
# [66 rows x 3 columns]

# %%
n_grad = 3
confspec = '32Pscrub3BPfilterrunFD104'

# %%
sub = '01'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))
data_fs5 = gm_aligned[n_grad-1]
data_fs7 = cortex.freesurfer.upsample_to_fsaverage(data_fs5, "fsaverage5")
vtx = cortex.Vertex(data_fs7, pyc_subject)
cortex.quickshow(vtx, with_curvature=True, with_colorbar=False) # , port=8000
plt.show()

# %%
sub = '06'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8000) # worked!!!
print(confspec)
#cortex.webshow(data=pyc_data, port=8000)
# Out:
# Started server on port 8000
# 32Pscrub3BPfilterrunFD104
# Stopping server

# %%
sub = '46'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8000) # worked!!!
#cortex.webshow(data=pyc_data, port=8000)

# %%
sub = '63'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8001)

# %%
sub = '66'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8002)

# %%
sub = '27'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8003)
# Out:
# Started server on port 8003

# %%
sub = '33'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8004)
# Out:
# Started server on port 8004

# %%
sub = '03'

source_folder_gm = op.join(bids_folder, 'derivatives', f'gradients.{confspec}', f'sub-{sub}')
gm_aligned = np.load(op.join(source_folder_gm,f'sub-{sub}_g-aligned_space-fsaverag5_n10.npy'))

data_grad1 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[1-1], "fsaverage5")
data_grad2 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[2-1], "fsaverage5")
data_grad3 = cortex.freesurfer.upsample_to_fsaverage(gm_aligned[3-1], "fsaverage5")

pyc_data = {
    f'sub-{sub}, grad-1': cortex.Vertex(data_grad1, pyc_subject),
    f'sub-{sub}, grad-2': cortex.Vertex(data_grad2, pyc_subject),
    f'sub-{sub}, grad-3': cortex.Vertex(data_grad3, pyc_subject),
    }
cortex.webgl.show(pyc_data, port=8005)
# Out:
# Started server on port 8005
# <JS: window.viewer>
# Stopping server
